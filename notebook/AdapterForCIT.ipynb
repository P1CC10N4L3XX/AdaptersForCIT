# %%
#@markdown # Connect Google Drive
from google.colab import drive
from IPython.display import clear_output
import ipywidgets as widgets
import os

def inf(msg, style, wdth): inf = widgets.Button(description=msg, disabled=True, button_style=style, layout=widgets.Layout(min_width=wdth));display(inf)
#@markdown Press the button to connect to google drive

print("[0;33mConnecting...")
drive.mount('/content/gdrive')


mainpth="MyDrive"

clear_output()
inf('\u2714 Done','success', '50px')

#@markdown ---

# %%
#@markdown # Install/Update AdapterForCIT repo
from IPython.utils import capture
from IPython.display import clear_output
from subprocess import getoutput
import ipywidgets as widgets
import sys
import fileinput
import os
import time
import base64
import requests
from urllib.request import urlopen, Request
from urllib.parse import urlparse, parse_qs, unquote
from tqdm import tqdm
import six


blsaphemy=base64.b64decode(("ZWJ1aQ==").encode('ascii')).decode('ascii')

if not os.path.exists("/content/gdrive"):
  print('[1;31mGdrive not connected, using temporary colab storage ...')
  time.sleep(4)
  mainpth="MyDrive"
  # !mkdir -p /content/gdrive/$mainpth


with capture.capture_output() as cap:
  def inf(msg, style, wdth): inf = widgets.Button(description=msg, disabled=True, button_style=style, layout=widgets.Layout(min_width=wdth));display(inf)
  # %cd /content/gdrive/$mainpth/
  # !git clone https://github.com/P1CC10N4L3XX/AdaptersForCIT
  # !mkdir -p /content/gdrive/$mainpth/AdaptersForCIT/logs

with capture.capture_output() as cap:
  # %cd /content/gdrive/$mainpth/AdaptersForCIT
  # !git reset --hard
  # !git checkout master
  time.sleep(1)
  # !rm webui.sh
  # !git pull
clear_output()
inf('\u2714 Done','success', '50px')

#@markdown ---

# %%
#@markdown #Train Adapter

def inf(msg, style, wdth): inf = widgets.Button(description=msg, disable=True, button_style=style, layout=widgets.Layout(min_width=wdth));display(inf)

model="HuggingFaceTB/SmolLM2-1.7B-Instruct" #@param = {type:"string"}

# !python train_adapter.py

inf('\u2714 Done','success', '50px')
#@markdown ---

# %%
#@markdown # Start benchmark
import ipywidgets as widgets
import os

def inf(msg, style, wdth): inf = widgets.Button(description=msg, disable=True, button_style=style, layout=widgets.Layout(min_width=wdth));display(inf)

model = "HuggingFaceTB/SmolLM2-1.7B-Instruct" #@param {type:"string"}
#@markdown
adapter_path = "" #@param {type:"string"}
#@markdown
domains = "GDPR" #@param {type:"string"}
#@markdown
log_file_name = "SmolLM.txt" #@param {type:"string"}

log_path = "logs/"+log_file_name

# !python benchmarkOnAdapter.py \
--model $model \
--adapter_path $adapter_path \
--domains $domains \
--log_path $log_path

inf('\u2714 Done','success', '50px')

#@markdown ---
